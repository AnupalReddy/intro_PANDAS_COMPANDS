# %% [markdown]
# <a href="https://colab.research.google.com/github/AnupalReddy/intro_PANDAS_COMPANDS/blob/main/pandas_intro_commands.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# The following code is in R. If you are using a Python kernel, you will need to switch to an R kernel or use a library like `rpy2` to execute it.

# %%
# Read the CSV file
df <- read.csv("/content/sample_data/mnist_train_small.csv")

# Display the structure of the data frame
print(str(df))

# Display the first few rows of the data frame
print(head(df))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1928645201.py in <cell line: 0>()
#       1 # Read the CSV file
# ----> 2 df <- read.csv("/content/sample_data/mnist_train_small.csv")
#       3
#       4 # Display the structure of the data frame
#       5 print(str(df))
#
# NameError: name 'read' is not defined

# %%
# Calculate the median of the 'gmat' column
median_gmat <- median(df$gmat, na.rm = TRUE)

# Print the median
print(paste("The median of the gmat column is:", median_gmat))

# %%
import pandas as pd

# %%
import pandas as pd

# %%
import pandas as pd

# %%
import pandas as pd

# %%
df=pd.read_csv('mba.csv')

# %%
df

# %%
df.head()

# %%
# to display last 5 records in the dataset
df.tail()

# %%
df.columns

# %%
df.shape

# %%
df.dtypes
# Out:
# Employee id       int64
# Employee name    object
# montly salary     int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Employee id    5 non-null      int64
#  1   Employee name  5 non-null      object
#  2   montly salary  5 non-null      int64
# dtypes: int64(2), object(1)
# memory usage: 252.0+ bytes

# %%
pd.set_option('display.max_rows',None)

# %%
df
# Out:
#    Employee id  Employee name  montly salary
# 0          101   Ankit Sharma          45000
# 1          102  Priynka singh          85000
# 2          103    Rohan Mehta          40000
# 3          104   Geetha patel          60000
# 4          105   Vishal kumar          35000

# %%
# to check for null values
df.isnull().sum()
# Out:
# Employee id      0
# Employee name    0
# montly salary    0
# dtype: int64

# %%
df.describe(include='all')
# Out:
#         Employee id Employee name  montly salary
# count      5.000000             5       5.000000
# unique          NaN             5            NaN
# top             NaN  Ankit Sharma            NaN
# freq            NaN             1            NaN
# mean     103.000000           NaN   53000.000000
# std        1.581139           NaN   20186.629238
# min      101.000000           NaN   35000.000000
# 25%      102.000000           NaN   40000.000000
# 50%      103.000000           NaN   45000.000000
# 75%      104.000000           NaN   60000.000000
# max      105.000000           NaN   85000.000000

# %%
df.mean(numeric_only=True)
# Out:
# Employee id        103.0
# montly salary    53000.0
# dtype: float64

# %%
df['Employee id'].mean()
# Out:
# np.float64(103.0)

# %%
df['Employee id'].median()
# Out:
# 103.0

# %%
df['montly salary'].mode()
# Out:
# 0    35000
# 1    40000
# 2    45000
# 3    60000
# 4    85000
# Name: montly salary, dtype: int64

# %%
df[['Employee id','montly salary']].mean()
# Out:
# Employee id        103.0
# montly salary    53000.0
# dtype: float64

# %%
df['Employee id'].var()
# Out:
# 2.5

# %%
df['Employee id'].std()
# Out:
# 1.5811388300841898

# %%
df['Employee id'].skew()
# Out:
# np.float64(0.0)

# %%
df['montly salary'].max()-df['montly salary'].min()
# Out:
# 50000

# %%
df['montly salary'].count()
# Out:
# np.int64(5)

# %%
df['montly salary'].value_counts()
# Out:
# montly salary
# 45000    1
# 85000    1
# 40000    1
# 60000    1
# 35000    1
# Name: count, dtype: int64

# %%
df.head()
# Out:
#    Employee id  Employee name  montly salary
# 0          101   Ankit Sharma          45000
# 1          102  Priynka singh          85000
# 2          103    Rohan Mehta          40000
# 3          104   Geetha patel          60000
# 4          105   Vishal kumar          35000

# %%
df.iloc[0:3,0:2]
# Out:
#    Employee id  Employee name
# 0          101   Ankit Sharma
# 1          102  Priynka singh
# 2          103    Rohan Mehta

# %%
df.groupby('montly salary')[['Employee id','Employee name']].mean(numeric_only=True)
# Out:
#                Employee id
# montly salary
# 35000                105.0
# 40000                103.0
# 45000                101.0
# 60000                104.0
# 85000                102.0
